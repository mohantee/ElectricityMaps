# %% [markdown]
# # Bronze Ingestion
# Test the Bronze layer ingestion independently.

# %%
from electricity_maps.layers.bronze import ingest_bronze
from electricity_maps.utils.state import PipelineState
from electricity_maps.config import get_settings

# %%
get_settings.cache_clear()
settings = get_settings()
state = PipelineState(settings)

# %%
print("Starting bronze ingestion")
result = ingest_bronze(settings)
print("Result:", result)
# Out:
# Starting bronze ingestion
# Result: {'process_ts': 1777136260728, 'start': '2026-04-25T15:00:00+00:00', 'end': '2026-04-25T16:00:00+00:00', 'mix_records': 1, 'flows_records': 1, 'mix_key': 's3://electricity-maps/data/bronze/electricity_mix/year=2026/month=04/day=25/FR_1777136260728.parquet', 'flows_key': 's3://electricity-maps/data/bronze/electricity_flows/year=2026/month=04/day=25/FR_1777136260728.parquet'}

# %%
print("Current state of el_state table after Bronze ingestion:")
display(state.get_state_summary())
# Out:
# Current state of el_state table after Bronze ingestion:
# shape: (4, 7)
# ┌─────────┬───────────────┬────────────────┬───────────────┬────────┬──────────────┬───────────────┐
# │ process ┆ process_ts    ┆ start_timestam ┆ end_timestamp ┆ status ┆ record_count ┆ error_message │
# │ ---     ┆ ---           ┆ p              ┆ ---           ┆ ---    ┆ ---          ┆ ---           │
# │ str     ┆ i64           ┆ ---            ┆ datetime[μs,  ┆ str    ┆ i64          ┆ str           │
# │         ┆               ┆ datetime[μs,   ┆ UTC]          ┆        ┆              ┆               │
# │         ┆               ┆ UTC]           ┆               ┆        ┆              ┆               │
# ╞═════════╪═══════════════╪════════════════╪═══════════════╪════════╪══════════════╪═══════════════╡
# │ bronze  ┆ 1777136260728 ┆ 2026-04-25 16: ┆ 2026-04-25    ┆ R      ┆ 2            ┆ null          │
# │         ┆               ┆ 57:40.728139   ┆ 16:57:55.4190 ┆        ┆              ┆               │
# │         ┆               ┆ UTC            ┆ 97 UTC        ┆        ┆              ┆               │
# │ gold    ┆ 1777129788867 ┆ 2026-04-25 15: ┆ 2026-04-25    ┆ R      ┆ 16           ┆ null          │
# │         ┆               ┆ 09:50.371386   ┆ 15:09:55.3539 ┆        ┆              ┆               │
# │         ┆               ┆ UTC            ┆ 71 UTC        ┆        ┆              ┆               │
# │ silver  ┆ 1777129719141 ┆ 2026-04-25 15: ┆ 2026-04-25    ┆ C      ┆ 197          ┆ null          │
# │         ┆               ┆ 08:45.969940   ┆ 15:08:51.6532 ┆        ┆              ┆               │
# │         ┆               ┆ UTC            ┆ 79 UTC        ┆        ┆              ┆               │
# │ bronze  ┆ 1777129595150 ┆ 2026-04-25 15: ┆ 2026-04-25    ┆ C      ┆ 48           ┆ null          │
# │         ┆               ┆ 06:35.150267   ┆ 15:06:44.0864 ┆        ┆              ┆               │
# │         ┆               ┆ UTC            ┆ 18 UTC        ┆        ┆              ┆               │
# └─────────┴───────────────┴────────────────┴───────────────┴────────┴──────────────┴───────────────┘
