# %% [markdown]
# # Bronze Ingestion
# Test the Bronze layer ingestion independently.

# %%
from datetime import datetime, timezone
from electricity_maps.layers.bronze import ingest
from electricity_maps.utils.state import PipelineState
from electricity_maps.config import get_settings

# %%
settings = get_settings()
state = PipelineState(settings.data_dir)

now = datetime.now(timezone.utc)
process_ts = int(now.timestamp())

# %%
print(f"Starting bronze ingestion with process_ts={process_ts} for zone FR")
ingest("FR", process_ts)
# Out:
# Starting bronze ingestion with process_ts=1777051344 for zone FR
# 2026-04-24T17:22:24.086938Z [info     ] Starting bronze ingestion      [electricity_maps.layers.bronze] process_ts=1777051344 zone=FR
# 2026-04-24T17:22:28.075852Z [info     ] el_state: layer initialized    [electricity_maps.utils.state] process=bronze process_ts=1777051344 status=I
# 2026-04-24T17:22:29.477608Z [info     ] Found previous run             [electricity_maps.layers.bronze] last_end_ts=2026-04-24T17:00:00+00:00 start_dt=2026-04-24T17:00:00+00:00
# 2026-04-24T17:22:29.484702Z [info     ] No new data to fetch           [electricity_maps.layers.bronze] end_dt=2026-04-24T17:00:00+00:00 start_dt=2026-04-24T17:00:00+00:00
# 2026-04-24T17:22:30.574892Z [info     ] el_state: layer marked ready   [electricity_maps.utils.state] process=bronze process_ts=1777051344 record_count=0 status=R

# %%
print("Current state of el_state table after Bronze ingestion:")
display(state.get_state_summary())
# Out:
# Current state of el_state table after Bronze ingestion:
# shape: (6, 7)
# ┌─────────┬────────────┬─────────────────┬─────────────────┬────────┬──────────────┬───────────────┐
# │ process ┆ process_ts ┆ start_timestamp ┆ end_timestamp   ┆ status ┆ record_count ┆ error_message │
# │ ---     ┆ ---        ┆ ---             ┆ ---             ┆ ---    ┆ ---          ┆ ---           │
# │ str     ┆ i64        ┆ datetime[μs,    ┆ datetime[μs,    ┆ str    ┆ i64          ┆ str           │
# │         ┆            ┆ UTC]            ┆ UTC]            ┆        ┆              ┆               │
# ╞═════════╪════════════╪═════════════════╪═════════════════╪════════╪══════════════╪═══════════════╡
# │ bronze  ┆ 1777051344 ┆ 2026-04-24      ┆ 2026-04-24      ┆ R      ┆ 0            ┆ null          │
# │         ┆            ┆ 17:22:24.086884 ┆ 17:22:24.086884 ┆        ┆              ┆               │
# │         ┆            ┆ UTC             ┆ UTC             ┆        ┆              ┆               │
# │ silver  ┆ 1777050550 ┆ 2026-04-24      ┆ 2026-04-24      ┆ R      ┆ 1            ┆ null          │
# │         ┆            ┆ 17:09:10.513941 ┆ 17:09:10.513941 ┆        ┆              ┆               │
# │         ┆            ┆ UTC             ┆ UTC             ┆        ┆              ┆               │
# │ bronze  ┆ 1777050504 ┆ 2026-04-24      ┆ 2026-04-24      ┆ C      ┆ 2            ┆ null          │
# │         ┆            ┆ 17:08:24.361390 ┆ 17:00:00 UTC    ┆        ┆              ┆               │
# │         ┆            ┆ UTC             ┆                 ┆        ┆              ┆               │
# │ gold    ┆ 1777045214 ┆ 2026-04-24      ┆ 2026-04-24      ┆ R      ┆ 1            ┆ null          │
# │         ┆            ┆ 15:40:14.139309 ┆ 15:40:14.139309 ┆        ┆              ┆               │
# │         ┆            ┆ UTC             ┆ UTC             ┆        ┆              ┆               │
# │ silver  ┆ 1777044781 ┆ 2026-04-24      ┆ 2026-04-24      ┆ C      ┆ 1            ┆ null          │
# │         ┆            ┆ 15:33:01.115612 ┆ 15:33:01.115612 ┆        ┆              ┆               │
# │         ┆            ┆ UTC             ┆ UTC             ┆        ┆              ┆               │
# │ bronze  ┆ 1777044705 ┆ 2026-04-24      ┆ 2026-04-24      ┆ C      ┆ 24           ┆ null          │
# │         ┆            ┆ 15:31:45.865108 ┆ 15:00:00 UTC    ┆        ┆              ┆               │
# │         ┆            ┆ UTC             ┆                 ┆        ┆              ┆               │
# └─────────┴────────────┴─────────────────┴─────────────────┴────────┴──────────────┴───────────────┘
