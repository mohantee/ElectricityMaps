# %% [markdown]
# # Bronze Ingestion
# Test the Bronze layer ingestion independently.

# %%
from electricity_maps.layers.bronze import ingest_bronze
from electricity_maps.utils.state import PipelineState
from electricity_maps.config import get_settings

# %%
get_settings.cache_clear()
settings = get_settings()
state = PipelineState(settings)

# %%
print("Starting bronze ingestion")
result = ingest_bronze(settings)
print("Result:", result)
# Out:
# Starting bronze ingestion
# 2026-04-25 18:31:34 [info     ] bronze_started                 process_ts=1777122094292
# 2026-04-25 18:31:35 [info     ] no_prior_run                   defaulting_start_to='2026-04-24 13:00:00+00:00'
# 2026-04-25 18:31:35 [info     ] bronze_time_range              end='2026-04-25 13:00:00+00:00' start='2026-04-24 13:00:00+00:00'
# 2026-04-25 18:31:36 [info     ] bronze_api_fetched             flows_records=24 mix_records=24
# 2026-04-25 18:31:37 [info     ] bronze_written_to_s3           flows_key='s3://electricity-maps/data/bronze/electricity_flows/year=2026/month=04/day=25/FR_1777122094292.parquet' mix_key='s3://electricity-maps/data/bronze/electricity_mix/year=2026/month=04/day=25/FR_1777122094292.parquet'
# 2026-04-25 18:31:38 [info     ] bronze_completed               total_records=48
# Result: {'process_ts': 1777122094292, 'start': '2026-04-24T13:00:00+00:00', 'end': '2026-04-25T13:00:00+00:00', 'mix_records': 24, 'flows_records': 24, 'mix_key': 's3://electricity-maps/data/bronze/electricity_mix/year=2026/month=04/day=25/FR_1777122094292.parquet', 'flows_key': 's3://electricity-maps/data/bronze/electricity_flows/year=2026/month=04/day=25/FR_1777122094292.parquet'}

# %%
print("Current state of el_state table after Bronze ingestion:")
display(state.get_state_summary())
# Out:
# Current state of el_state table after Bronze ingestion:
# shape: (1, 7)
# ┌─────────┬───────────────┬────────────────┬───────────────┬────────┬──────────────┬───────────────┐
# │ process ┆ process_ts    ┆ start_timestam ┆ end_timestamp ┆ status ┆ record_count ┆ error_message │
# │ ---     ┆ ---           ┆ p              ┆ ---           ┆ ---    ┆ ---          ┆ ---           │
# │ str     ┆ i64           ┆ ---            ┆ datetime[μs,  ┆ str    ┆ i64          ┆ str           │
# │         ┆               ┆ datetime[μs,   ┆ UTC]          ┆        ┆              ┆               │
# │         ┆               ┆ UTC]           ┆               ┆        ┆              ┆               │
# ╞═════════╪═══════════════╪════════════════╪═══════════════╪════════╪══════════════╪═══════════════╡
# │ bronze  ┆ 1777122094292 ┆ 2026-04-25 13: ┆ 2026-04-25    ┆ R      ┆ 48           ┆ null          │
# │         ┆               ┆ 01:34.292375   ┆ 13:01:37.3693 ┆        ┆              ┆               │
# │         ┆               ┆ UTC            ┆ 83 UTC        ┆        ┆              ┆               │
# └─────────┴───────────────┴────────────────┴───────────────┴────────┴──────────────┴───────────────┘
